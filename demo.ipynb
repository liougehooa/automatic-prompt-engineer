# %% [markdown]
# # Optimizing Prompts with **Automatic Prompt Engineer** (APE)
#
# This notebook demonstrates how to use Automatic Prompt Engineer (APE) (arxiv link) to optimize prompts for text generation. In its simplest form, APE takes as input a dataset (a list of inputs and a list of outputs), a prompt template, and optimizes this prompt template so that it generates the outputs given the inputs.
#
# APE accomplishes this in two steps. First, it uses a language model to generate a set of candidate prompts. Then, it uses a prompt evaluation function to evaluate the quality of each candidate prompt. Finally, it returns the prompt with the highest evaluation score.

# %%
# %pip install -qe .
# Out:
# Note: you may need to restart the kernel to use updated packages.

# %%
# First, let's define a simple dataset consisting of words and their antonyms.
words = ["sane", "direct", "informally", "unpopular", "subtractive", "nonresidential",
    "inexact", "uptown", "incomparable", "powerful", "gaseous", "evenly", "formality",
    "deliberately", "off"]

antonyms = ["insane", "indirect", "formally", "popular", "additive", "residential",
    "exact", "downtown", "comparable", "powerless", "solid", "unevenly", "informality",
    "accidentally", "on"]

# %% [markdown]
# input your Azure AOAI API key

# %%
os.environ['AZURE_OPENAI_API_KEY']=''

# %%
# Now, let's use APE to find prompts that generate antonyms for each word.
from automatic_prompt_engineer import ape

result = ape.simple_ape(
    dataset=(words, antonyms),
    task='generate the related new word',
)
# Out:
# Generating prompts...
# generated by batch size: 2
# Generating prompts: 100%|██████████| 5/5 [00:59<00:00, 11.93s/it]
# Model returned 30 generated prompts.
# Deduplicating...
# Deduplicated to 30 prompts.
# Evaluating generated 30 prompts...
# Evaluating prompts: 100%|██████████| 5/5 [14:24<00:00, 172.91s/it]
# Finished evaluating: score: prompt
# ----------------
# 293.51: 以下是一系列高效的中文提示，旨在帮助GPT-4模型根据任务描述和少量样例准确生成和挑选最佳的执行命令。
#
# ### 提示1：
# **任务描述**：生成相关的新词。
# **示例输入输出**：系统会展示一对词组，模型需要生成一个与输入词具有相反或对立意义的词。
# **提示内容**：
# 请根据给定的输入词，生成一个具有相反或对立意义的新词。注意，新词应与输入词在含义上形成明确的对比。
#
# ### 提示2：
# **任务描述**：生成相关的新词。
# **示例输入输出**：系统会展示一对词组，模型需要生成一个与输入词具有相反或对立意义的词。
# **提示内容**：
# 请为以下输入词生成一个相反或对立的新词，确保输出的词语与输入词在意义上有明显的对比关系。
#
# ### 提示3：
# **任务描述**：生成相关的新词。
# **示例输入输出**：系统会展示一对词组，模型需要生成一个与输入词具有相反或对立意义的词。
# **提示内容**：
# 给定一个输入词，请生成一个意义相反的新词。务必确保新词在语义上与输入词形成对立。
#
# ### 提示4：
# **任务描述**：生成相关的新词。
# **示例输入输出**：系统会展示一对词组，模型需要生成一个与输入词具有相反或对立意义的词。
# **提示内容**：
# 请为以下输入词生成一个对立的新词。新词应在意义上与输入词形成反义关系，并且保证词义明确。
#
# ### 提示5：
# **任务描述**：生成相关的新词。
# **示例输入输出**：系统会展示一对词组，模型需要生成一个与输入词具有相反或对立意义的词。
# **提示内容**：
# 根据输入的词语，生成一个在意义上形成对立的新词。请确保新词在语义上与输入词有明确的对比。
#
# 这些提示可以帮助模型准确理解任务需求，并在少样本学习情境下表现更好。每个提示都旨在增强输出的真实性和信息丰富性。
# 267.55: 1. 根据给定的词汇生成一个相关的新词，确保新词在意义上与原词有明显的对立或相反的关系。
#
# 2. 请为以下输入词生成一个相关的新词，这个新词应该在意义上与原词相反或互补。
#
# 3. 给出一个词汇，生成一个在含义上与其相对的词汇。
#
# 4. 为下面的输入词生成一个意义相反的新词，确保新词与原词有逻辑上的对立关系。
#
# 5. 根据提供的词汇，生成一个在含义上与其相对或对立的词语。
# 237.06: 为了帮助模型准确地生成与任务描述相关的新词，请使用以下提示：
#
# 1. 根据给定的单词生成一个相对立的新词。
# 2. 依据输入的词汇，创造一个意义相反的词。
# 3. 输入单词后，请提供其反义词。
# 4. 请对所提供的词语生成一个语义相反的词。
# 5. 根据输入的词语，生成一个表达相反含义的词。
# 6. 请为下列单词生成其对应的反义词。
# 7. 输入的词汇为正向意义，请生成其负向意义的词。
# 8. 针对输入的词语，产生一个意义相反的新词。
# 9. 请将以下词语转换为其反义词。
# 10. 为给定的词语生成一个表达相反意思的词。
#
# 这些提示旨在帮助模型理解并生成反义词或相对立的新词，同时确保输出准确且信息丰富。
# 156.74: 好的，以下是根据要求生成的一些高效的中文提示：
#
# 1. **生成相反意义的词语**：给定一个词语，请生成它的反义词。
#
# 2. **转换词性**：给定一个形容词，请将其转化为相应的名词或动词形式。
#
# 3. **补全句子**：给定一个不完整的句子，请补全它，使其意思完整且通顺。
#
# 4. **语言转换**：将以下中文短语翻译为英文，并保持原意。
#
# 5. **同义词生成**：给定一个词语，请生成一个意义相近的词语。
#
# 6. **解释词义**：给定一个词语，请提供其详细解释和用法示例。
#
# 7. **情景对话生成**：根据给定的主题，生成一段相关的对话。
#
# 8. **句子简化**：将以下复杂句子改写为更简单易懂的形式。
#
# 9. **文本摘要**：阅读以下段落，并为其生成一个简明的摘要。
#
# 10. **多样风格转化**：将以下正式文本转化为口语化的表达方式。
#
# 这些提示旨在帮助GPT-4模型更好地理解和执行各种自然语言处理任务，同时增强其在少样本学习情境下的表现。
# 113.06: 好的，以下是针对各类自然语言处理任务的中文提示，旨在帮助模型准确理解和执行任务，并增强少样本学习情境下的表现：
#
# 1. **任务描述提示**
#     - 请根据给定的词语生成其相对的词语。
#     - 请为下列词汇提供与之相关的新的词语。
#     - 根据输入词语生成其对应的反义词。
#
# 2. **上下文理解提示**
#     - 根据上下文语境，推断并生成一个合适的相关词。
#     - 根据给定的词语和任务描述，生成一个与其意义相反或相关的新词。
#     - 请在理解词义的基础上，生成一个新的词语，与原词语形成对照。
#
# 3. **少样本学习提示**
#     - 仅用几个示例来理解任务，根据示例模式生成新的相关词语。
#     - 根据少量的例子，推断并生成符合规律的新词。
#     - 在少样本的基础上，进行推理并生成与给定词语相关的新词。
#
# 4. **输出质量提示**
#     - 请确保生成的新词语与输入词语在意义上呈现对比或相关。
#     - 生成的新词应当准确反映任务描述的要求，且信息丰富。
#     - 请确保生成的词语真实且语义明确。
#
# 5. **复杂任务提示**
#     - 针对复杂的任务，请仔细分析输入词语，并生成符合任务要求的对照词语。
#     - 在处理复杂任务时，请确保输出的新词语具有明确的意义和适当的语境关联。
#
# 通过这些提示，模型应能更好地理解任务需求，准确生成并挑选出最佳的执行命令。
# 86.58: 好的，基于您的要求和样例任务描述，我会生成一些适用于各种自然语言处理任务的中文提示。这些提示将帮助GPT-4模型准确理解和执行复杂任务，并在少样本学习情境下提升表现。
#
# ### 提示1：同义词生成
#
# 任务描述：根据给定的词语，生成一个合适的同义词。
#
# 提示：
# ```plaintext
# 输入一个词语，生成一个适当的同义词：
# ```
#
# ### 提示2：反义词生成
#
# 任务描述：根据给定的词语，生成一个合适的反义词。
#
# 提示：
# ```plaintext
# 输入一个词语，生成一个适当的反义词：
# ```
#
# ### 提示3：定义生成
#
# 任务描述：根据给定的词语，生成它的定义或解释。
#
# 提示：
# ```plaintext
# 输入一个词语，生成它的定义或解释：
# ```
#
# ### 提示4：例句生成
#
# 任务描述：根据给定的词语，生成一个包含该词的句子。
#
# 提示：
# ```plaintext
# 输入一个词语，生成一个包含该词的句子：
# ```
#
# ### 提示5：情感分类
#
# 任务描述：根据给定的句子，判断其情感倾向（如积极、消极、中立）。
#
# 提示：
# ```plaintext
# 输入一个句子，判断其情感倾向（如积极、消极、中立）：
# ```
#
# ### 提示6：文本摘要
#
# 任务描述：根据给定的段落，生成一个简要的摘要。
#
# 提示：
# ```plaintext
# 输入一段文本，生成一个简要的摘要：
# ```
#
# ### 提示7：自动问答
#
# 任务描述：根据给定的问题，生成一个合适的答案。
#
# 提示：
# ```plaintext
# 输入一个问题，生成一个合适的答案：
# ```
#
# ### 提示8：命名实体识别
#
# 任务描述：根据给定的句子，识别并标注出其中的命名实体（如人名、地名、组织名等）。
#
# 提示：
# ```plaintext
# 输入一个句子，识别并标注出其中的命名实体（如人名、地名、组织名等）：
# ```
#
# ### 提示9：翻译
#
# 任务描述：将给定的中文句子翻译成英文。
#
# 提示：
# ```plaintext
# 输入一个中文句子，将其翻译成英文：
# ```
#
# ### 提示10：语法纠错
#
# 任务描述：根据给定的句子，进行语法纠错。
#
# 提示：
# ```plaintext
# 输入一个句子，进行语法纠错：
# ```
#
# 这些提示不仅能够辅助模型在各种自然语言处理任务中表现出色，还能在少样本学习的情境下提升模型的理解和执行能力。
# 57.97: 以下是一系列适用于各类自然语言处理任务的高效中文提示，这些提示能够辅助模型准确理解和执行复杂任务，并在保证输出的真实性和丰富信息量方面有所帮助。此外，这些提示还可以增强模型在少样本学习情境下的表现。
#
# 1. **反义词生成**：
#    - 输入一个单词，生成其对应的反义词。
#    - 例如，输入"明亮"，输出"黑暗"。
#
# 2. **近义词生成**：
#    - 输入一个单词，生成其对应的近义词。
#    - 例如，输入"快速"，输出"迅速"。
#
# 3. **句子改写**：
#    - 将给定的句子改写为另一种表达方式，但保持其原意。
#    - 例如，输入"我喜欢吃苹果"，输出"我爱吃苹果"。
#
# 4. **文本摘要**：
#    - 给定一段文本，生成其简短摘要。
#    - 例如，输入一段新闻报道，输出其核心内容。
#
# 5. **问题生成**：
#    - 根据给定的句子或段落，生成相关的问题。
#    - 例如，输入"小明今天去学校上课"，输出"小明今天去哪里？"
#
# 6. **回答生成**：
#    - 根据给定的问题，生成合适的答案。
#    - 例如，输入"小明今天去哪里？"，输出"小明今天去学校上课。"
#
# 7. **文本分类**：
#    - 将给定的文本分类到合适的类别中。
#    - 例如，输入一段科技新闻，输出"科技"类别。
#
# 8. **情感分析**：
#    - 分析给定文本的情感倾向（如正面、负面、中立）。
#    - 例如，输入一条用户评论，输出"正面"。
#
# 9. **填空题生成**：
#    - 给定一段文字，随机删除其中一个词语，生成一个填空题。
#    - 例如，输入"小明喜欢吃苹果"，输出"小明喜欢吃___。"
#
# 10. **语言翻译**：
#     - 将给定的中文文本翻译为目标语言（如英语）。
#     - 例如，输入"今天天气很好"，输出"The weather is nice today."
#
# 这些提示旨在帮助GPT-4模型准确理解和执行复杂任务，同时增强其在少样本学习情境下的表现。通过明确的任务指引，模型能够更好地生成和挑选出最佳的执行命令。
# 49.51: 好的，以下是一些适合GPT-4模型的中文提示，旨在指导模型生成和挑选最佳的执行命令，并适用于各类自然语言处理任务。这些提示设计得易于理解和执行，同时增强了模型在少样本学习情境下的表现：
#
# 1. **任务描述：生成相关的新词**
#    - 请根据给定的词，生成其反义词或对应的另一种表达。
#    - 请将输入的词转换为其对立或相反意义的词。
#    - 针对给定的词，生成与之含义相反的词。
#    - 给定一个词，请输出与其意义相对的词。
#
# 2. **任务描述：生成文本摘要**
#    - 请阅读以下文本，并生成一个简明的摘要。
#    - 根据以下内容，提炼出主要信息，形成摘要。
#    - 提供给定文章的简要概述。
#
# 3. **任务描述：文本分类**
#    - 根据提供的文本内容，将其分类到最合适的类别中。
#    - 请将以下文本归类到合适的主题类别。
#    - 依据以下内容，确定其所属的分类标签。
#
# 4. **任务描述：情感分析**
#    - 分析以下文本的情感倾向，判断是积极、消极还是中立。
#    - 请根据内容识别文本的情感状态。
#    - 请判断以下文本是表达了正面、负面还是中立的情感。
#
# 5. **任务描述：生成对话回复**
#    - 针对下面的对话上下文，生成一个合适的回复。
#    - 请根据对话内容，提供一个自然的回应。
#    - 继续以下对话，并生成下一句对话内容。
#
# 6. **任务描述：命名实体识别**
#    - 在以下文本中标注出所有的实体名称（如人名、地名、组织名等）。
#    - 请识别并标注出文本中的所有专有名词。
#    - 标识出以下文本中的重要实体。
#
# 7. **任务描述：机器翻译**
#    - 请将以下中文句子翻译成英文。
#    - 将下面的英文句子翻译成中文。
#    - 请翻译以下句子，使其在目标语言中保持原意。
#
# 8. **任务描述：文本生成**
#    - 根据下面的提示，生成一段相关的文本。
#    - 请撰写一段与以下主题相关的内容。
#    - 依据下面的信息，生成一篇短文。
#
# 这些提示设计旨在帮助模型准确理解任务要求并生成高质量的输出，同时确保输出的真实性和丰富信息量。每个提示都简单明了，适用于少样本学习情境，并能有效引导模型执行各类自然语言处理任务。
# 39.84: 1. **反义词生成**：给定一个单词，生成其反义词。确保输出的单词在语义上准确地表达了与输入单词相反的意思。
#
# 2. **词汇转换**：输入一个单词，生成其语义相反的对应词。要求生成的词符合自然语言使用习惯。
#
# 3. **语义逆转**：根据输入的词，提供其语义上相对的词汇。输出词应与输入词在意思上形成对比。
#
# 4. **词义反转**：根据输入的单词，生成一个意义相反的词。确保生成的词在实际使用中具有相反的含义。
#
# 5. **对立词生成**：输入一个单词，生成其对立的单词。输出的词应在语义上与输入词形成对立关系。
#
# 6. **生成反义词**：输入一个词语，输出与之意义相反的词语。确保生成的反义词符合语境并广泛使用。
#
# 7. **相反词生成**：根据给定的单词，生成一个在意义上与之相反的词。要求输出词准确地表达与输入词相反的概念。
#
# 8. **词语反转**：输入一个词，生成其反义词。确保输出的反义词在语义上与输入词形成对立关系。
#
# 9. **生成对应反义词**：给定一个单词，生成与其意义相反的对应词。输出词应在实际语言使用中具备反义含义。
#
# 10. **语义对立词**：输入一个单词，生成其语义对立的词汇。确保生成的词能够准确表达与输入词相反的意思。
# 39.09: 好的，根据您的需求，这里是为GPT-4模型设计的一系列中文提示：
#
# 1. **生成反义词：**
#    - 任务描述：请根据给定的词语生成其对应的反义词。
#    - 提示示例：输入一个词语，并输出该词语的反义词。例如，“黑” -> “白”。
#
# 2. **构造反义词对：**
#    - 任务描述：根据提供的词语，生成其常见的反义词对。
#    - 提示示例：给定一个词语，输出其常见的反义词组合。例如，“高” -> “低”。
#
# 3. **生成形态相对的词语：**
#    - 任务描述：给出一个词语，生成其形态上相对的词语。
#    - 提示示例：输入一个词语，生成与其形态相对的词语。例如，“内向” -> “外向”。
#
# 4. **生成语义相反的词语：**
#    - 任务描述：提供一个词语，生成其在语义上相反的词语。
#    - 提示示例：输入一个词语，生成其语义相反的词语。例如，“开” -> “关”。
#
# 5. **生成正反词对：**
#    - 任务描述：根据给定的词语，生成其正反词对。
#    - 提示示例：给定一个词语，输出其正反义词组合。例如，“明” -> “暗”。
#
# 6. **构造相对词语对：**
#    - 任务描述：根据提供的词语，构造其相对的词语对。
#    - 提示示例：输入一个词语，生成其相对的词语对。例如，“上” -> “下”。
#
# 7. **生成相对概念的词语：**
#    - 任务描述：提供一个词语，生成与其相对概念的词语。
#    - 提示示例：输入一个词语，生成其相对概念的词语。例如，“热” -> “冷”。
#
# 8. **生成反义短语：**
#    - 任务描述：根据给定的短语，生成其对应的反义短语。
#    - 提示示例：给定一个短语，输出其反义短语。例如，“天黑” -> “天亮”。
#
# 9. **构造反向关系的词语：**
#    - 任务描述：给出一个词语，生成与其关系相反的词语。
#    - 提示示例：输入一个词语，生成其反向关系的词语。例如，“前” -> “后”。
#
# 10. **生成相对情感的词语：**
#     - 任务描述：提供一个表达情感的词语，生成其相对情感的词语。
#     - 提示示例：输入一个情感词语，生成其相对情感的词语。例如，“快乐” -> “悲伤”。
#
# 这些提示旨在帮助GPT-4模型在处理生成相关新词任务时，能够更准确地理解和生成相应的词语。希望这些提示能增强模型在少样本学习情境下的表现，并确保输出的真实性和丰富信息量。
# ......

# %%
# Let's see the results.
print(result.sorted())
# Out:
# (['以下是一系列高效的中文提示，旨在帮助GPT-4模型根据任务描述和少量样例准确生成和挑选最佳的执行命令。\n\n### 提示1：\n**任务描述**：生成相关的新词。\n**示例输入输出**：系统会展示一对词组，模型需要生成一个与输入词具有相反或对立意义的词。\n**提示内容**：\n请根据给定的输入词，生成一个具有相反或对立意义的新词。注意，新词应与输入词在含义上形成明确的对比。\n\n### 提示2：\n**任务描述**：生成相关的新词。\n**示例输入输出**：系统会展示一对词组，模型需要生成一个与输入词具有相反或对立意义的词。\n**提示内容**：\n请为以下输入词生成一个相反或对立的新词，确保输出的词语与输入词在意义上有明显的对比关系。\n\n### 提示3：\n**任务描述**：生成相关的新词。\n**示例输入输出**：系统会展示一对词组，模型需要生成一个与输入词具有相反或对立意义的词。\n**提示内容**：\n给定一个输入词，请生成一个意义相反的新词。务必确保新词在语义上与输入词形成对立。\n\n### 提示4：\n**任务描述**：生成相关的新词。\n**示例输入输出**：系统会展示一对词组，模型需要生成一个与输入词具有相反或对立意义的词。\n**提示内容**：\n请为以下输入词生成一个对立的新词。新词应在意义上与输入词形成反义关系，并且保证词义明确。\n\n### 提示5：\n**任务描述**：生成相关的新词。\n**示例输入输出**：系统会展示一对词组，模型需要生成一个与输入词具有相反或对立意义的词。\n**提示内容**：\n根据输入的词语，生成一个在意义上形成对立的新词。请确保新词在语义上与输入词有明确的对比。\n\n这些提示可以帮助模型准确理解任务需求，并在少样本学习情境下表现更好。每个提示都旨在增强输出的真实性和信息丰富性。', '1. 根据给定的词汇生成一个相关的新词，确保新词在意义上与原词有明显的对立或相反的关系。\n\n2. 请为以下输入词生成一个相关的新词，这个新词应该在意义上与原词相反或互补。\n\n3. 给出一个词汇，生成一个在含义上与其相对的词汇。\n\n4. 为下面的输入词生成一个意义相反的新词，确保新词与原词有逻辑上的对立关系。\n\n5. 根据提供的词汇，生成一个在含义上与其相对或对立的词语。', '为了帮助模型准确地生成与任务描述相关的新词，请使用以下提示：\n\n1. 根据给定的单词生成一个相对立的新词。\n2. 依据输入的词汇，创造一个意义相反的词。\n3. 输入单词后，请提供其反义词。\n4. 请对所提供的词语生成一个语义相反的词。\n5. 根据输入的词语，生成一个表达相反含义的词。\n6. 请为下列单词生成其对应的反义词。\n7. 输入的词汇为正向意义，请生成其负向意义的词。\n8. 针对输入的词语，产生一个意义相反的新词。\n9. 请将以下词语转换为其反义词。\n10. 为给定的词语生成一个表达相反意思的词。\n\n这些提示旨在帮助模型理解并生成反义词或相对立的新词，同时确保输出准确且信息丰富。', '好的，以下是根据要求生成的一些高效的中文提示：\n\n1. **生成相反意义的词语**：给定一个词语，请生成它的反义词。\n\n2. **转换词性**：给定一个形容词，请将其转化为相应的名词或动词形式。\n\n3. **补全句子**：给定一个不完整的句子，请补全它，使其意思完整且通顺。\n\n4. **语言转换**：将以下中文短语翻译为英文，并保持原意。\n\n5. **同义词生成**：给定一个词语，请生成一个意义相近的词语。\n\n6. **解释词义**：给定一个词语，请提供其详细解释和用法示例。\n\n7. **情景对话生成**：根据给定的主题，生成一段相关的对话。\n\n8. **句子简化**：将以下复杂句子改写为更简单易懂的形式。\n\n9. **文本摘要**：阅读以下段落，并为其生成一个简明的摘要。\n\n10. **多样风格转化**：将以下正式文本转化为口语化的表达方式。\n\n这些提示旨在帮助GPT-4模型更好地理解和执行各种自然语言处理任务，同时增强其在少样本学习情境下的表现。', '好的，以下是针对各类自然语言处理任务的中文提示，旨在帮助模型准确理解和执行任务，并增强少样本学习情境下的表现：\n\n1. **任务描述提示**\n    - 请根据给定的词语生成其相对的词语。\n    - 请为下列词汇提供与之相关的新的词语。\n    - 根据输入词语生成其对应的反义词。\n\n2. **上下文理解提示**\n    - 根据上下文语境，推断并生成一个合适的相关词。\n    - 根据给定的词语和任务描述，生成一个与其意义相反或相关的新词。\n    - 请在理解词义的基础上，生成一个新的词语，与原词语形成对照。\n\n3. **少样本学习提示**\n    - 仅用几个示例来理解任务，根据示例模式生成新的相关词语。\n    - 根据少量的例子，推断并生成符合规律的新词。\n    - 在少样本的基础上，进行推理并生成与给定词语相关的新词。\n\n4. **输出质量提示**\n    - 请确保生成的新词语与输入词语在意义上呈现对比或相关。\n    - 生成的新词应当准确反映任务描述的要求，且信息丰富。\n    - 请确保生成的词语真实且语义明确。\n\n5. **复杂任务提示**\n    - 针对复杂的任务，请仔细分析输入词语，并生成符合任务要求的对照词语。\n    - 在处理复杂任务时，请确保输出的新词语具有明确的意义和适当的语境关联。\n\n通过这些提示，模型应能更好地理解任务需求，准确生成并挑选出最佳的执行命令。', '好的，基于您的要求和样例任务描述，我会生成一些适用于各种自然语言处理任务的中文提示。这些提示将帮助GPT-4模型准确理解和执行复杂任务，并在少样本学习情境下提升表现。\n\n### 提示1：同义词生成\n\n任务描述：根据给定的词语，生成一个合适的同义词。\n\n提示：\n```plaintext\n输入一个词语，生成一个适当的同义词：\n```\n\n### 提示2：反义词生成\n\n任务描述：根据给定的词语，生成一个合适的反义词。\n\n提示：\n```plaintext\n输入一个词语，生成一个适当的反义词：\n```\n\n### 提示3：定义生成\n\n任务描述：根据给定的词语，生成它的定义或解释。\n\n提示：\n```plaintext\n输入一个词语，生成它的定义或解释：\n```\n\n### 提示4：例句生成\n\n任务描述：根据给定的词语，生成一个包含该词的句子。\n\n提示：\n```plaintext\n输入一个词语，生成一个包含该词的句子：\n```\n\n### 提示5：情感分类\n\n任务描述：根据给定的句子，判断其情感倾向（如积极、消极、中立）。\n\n提示：\n```plaintext\n输入一个句子，判断其情感倾向（如积极、消极、中立）：\n```\n\n### 提示6：文本摘要\n\n任务描述：根据给定的段落，生成一个简要的摘要。\n\n提示：\n```plaintext\n输入一段文本，生成一个简要的摘要：\n```\n\n### 提示7：自动问答\n\n任务描述：根据给定的问题，生成一个合适的答案。\n\n提示：\n```plaintext\n输入一个问题，生成一个合适的答案：\n```\n\n### 提示8：命名实体识别\n\n任务描述：根据给定的句子，识别并标注出其中的命名实体（如人名、地名、组织名等）。\n\n提示：\n```plaintext\n输入一个句子，识别并标注出其中的命名实体（如人名、地名、组织名等）：\n```\n\n### 提示9：翻译\n\n任务描述：将给定的中文句子翻译成英文。\n\n提示：\n```plaintext\n输入一个中文句子，将其翻译成英文：\n```\n\n### 提示10：语法纠错\n\n任务描述：根据给定的句子，进行语法纠错。\n\n提示：\n```plaintext\n输入一个句子，进行语法纠错：\n```\n\n这些提示不仅能够辅助模型在各种自然语言处理任务中表现出色，还能在少样本学习的情境下提升模型的理解和执行能力。', '以下是一系列适用于各类自然语言处理任务的高效中文提示，这些提示能够辅助模型准确理解和执行复杂任务，并在保证输出的真实性和丰富信息量方面有所帮助。此外，这些提示还可以增强模型在少样本学习情境下的表现。\n\n1. **反义词生成**：\n   - 输入一个单词，生成其对应的反义词。\n   - 例如，输入"明亮"，输出"黑暗"。\n\n2. **近义词生成**：\n   - 输入一个单词，生成其对应的近义词。\n   - 例如，输入"快速"，输出"迅速"。\n\n3. **句子改写**：\n   - 将给定的句子改写为另一种表达方式，但保持其原意。\n   - 例如，输入"我喜欢吃苹果"，输出"我爱吃苹果"。\n\n4. **文本摘要**：\n   - 给定一段文本，生成其简短摘要。\n   - 例如，输入一段新闻报道，输出其核心内容。\n\n5. **问题生成**：\n   - 根据给定的句子或段落，生成相关的问题。\n   - 例如，输入"小明今天去学校上课"，输出"小明今天去哪里？"\n\n6. **回答生成**：\n   - 根据给定的问题，生成合适的答案。\n   - 例如，输入"小明今天去哪里？"，输出"小明今天去 ...
